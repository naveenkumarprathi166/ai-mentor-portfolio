# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenkumarprathi166/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines a progression of AI understanding and expertise, from foundational knowledge to advanced leadership:
#
# *   **1. AI Literacy:** Foundational understanding of what AI is, its basic capabilities, limitations, and societal impact.
# *   **2. AI Application:** Practical skills in effectively using existing AI tools and platforms (e.g., prompt engineering for LLMs).
# *   **3. AI Development:** Technical expertise in designing, building, training, and deploying AI models and systems.
# *   **4. AI Research & Leadership:** Pushing the boundaries of AI innovation, setting ethical guidelines, and leading strategic AI initiatives.
